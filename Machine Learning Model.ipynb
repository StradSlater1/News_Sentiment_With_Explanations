# %%
import pandas as pd
import numpy as np
from ast import literal_eval

# %% [markdown]
# # Feature Engineering

# %%
# Function to convert string items to ints
def convert_list_of_strings_to_ints(lst):
    return [int(item) for item in lst]

# Convert a string into the list contained within the string
def safe_literal_eval(val):
    try:
        return literal_eval(val)
    except (ValueError, SyntaxError):
        return None  

data = pd.read_csv('encoding_data.csv', encoding='utf-8', converters={
    'Phrases': lambda x: literal_eval(x.replace(r"\\", "")),
    'Values': lambda x: convert_list_of_strings_to_ints(safe_literal_eval(x))
})

# %% [markdown]
# ### Statistical Features of Each Sentence

# %%
import statistics

# Function to extract features from each sentence such as 
    # Mean of confidence scores and differences between original confidence score and score with phrase/word missing
    # std of confidence scores and differences between original confidence score and score with phrase/word missing
    # Max of confidence scores and differences between original confidence score and score with phrase/word missing
    # Min of confidence scores and differences between original confidence score and score with phrase/word missing
    # Range of confidence scores and differences between original confidence score and score with phrase/word missing
    # Amount of phrases/words that when removed have a confidence difference above 0.3, 0.2, 0.1
    # Amount of phrases/words that when removed have a confidence difference below -0.1, -0.2, -0.3
    # Amount of phrases/words that when removed have a confidence difference between 0.5 and -0.5
    # Number of words in a sentence
    # Number of words/phrases that when removed cause the sentiment label of the sentence to change
def get_features(row):
    differences = []
    confidence_scores = []
    amount_change = 0
    
    sent_results = sentiment_analyzer(row['Sentence'])
    sent_label = sent_results[0]['label']
    sent_score = sent_results[0]['score']
    
    above_0_05 = 0
    above_0_1 = 0
    above_0_2 = 0
    above_0_3 = 0
    
    below_0_05 = 0
    below_0_1 = 0
    below_0_2 = 0
    below_0_3 = 0
    
    between_0_05  = 0

    for phrase in row['Phrases']:
        new_sent = row['Sentence']
        new_sent = new_sent.replace(phrase, "")
        results = sentiment_analyzer(new_sent)
        new_score = results[0]['score']
        new_label = results[0]['label']
        difference = sent_score - new_score
        if new_label == sent_label:
            differences.append((sent_score - new_score))
            confidence_scores.append(new_score)
        else:
            amount_change += 1
            
        if difference > 0.3:
            above_0_3 += 1
        elif difference > 0.2:
            above_0_2 += 1
        elif difference > 0.1:
            above_0_1 += 1
        elif difference > 0.05:
            above_0_05 += 1
        elif difference < -0.3:
            below_0_3 += 1
        elif difference < -0.2:
            below_0_2 += 1
        elif difference < -0.1:
            below_0_1 += 1
        elif difference < -0.05:
            below_0_05 += 1
        else:
            between_0_05 += 1
            
            
    num_words = len(row['Sentence'].split(' '))
    
    row['word_number'] = num_words
    row['mean_confidence_difference'] = statistics.mean(differences) if differences else 0
    row['max_confidence_difference'] = max(differences) if differences else 0
    row['min_confidence_difference'] = min(differences) if differences else 0
    row['range_confidence_difference'] = (max(differences) - min(differences)) if differences else 0
    row['std_confidence_difference'] = statistics.stdev(differences) if len(differences) > 1 else 0
    
    row['mean_confidence'] = statistics.mean(confidence_scores) if confidence_scores else 0
    row['max_confidence'] = max(confidence_scores) if confidence_scores else 0
    row['min_confidence'] = min(confidence_scores) if confidence_scores else 0
    row['range_confidence'] = (max(confidence_scores) - min(confidence_scores)) if confidence_scores else 0
    row['std_confidence'] = statistics.stdev(confidence_scores) if len(confidence_scores) > 1 else 0
    
    row['original_confidence'] = sent_score
    row['original_label'] = sent_label
    
    row['amount_label_switched'] = amount_change
    
    row['above_0.05'] = above_0_05
    row['above_0.1'] = above_0_1
    row['above_0.2'] = above_0_2
    row['above_0.3'] = above_0_3
    row['below_-0.05'] = below_0_05
    row['below_-0.1'] = below_0_1
    row['below_-0.2'] = below_0_2
    row['below_-0.3'] = below_0_3
    row['between_+-0.05'] = between_0_05
    
    print(row['Unnamed: 0'])
    return row

# %%
# Extract statistical features from the data
data = data.apply(lambda x: get_features(x), axis=1)

# %%
#data.to_csv('data_w_features.csv')

# %% [markdown]
# ### Confidence Scores and Differences for Each Phrase

# %%
expanded_rows = []

# Create a new row for each phrase/word in a sentence
for _, row in data.iterrows():
    for phrase, value in zip(row['Phrases'], row['Values']):
        # Create a copy of the row for each phrase
        new_row = row.copy()
        # Replace the Phrases and Values columns with the single phrase and corresponding value
        new_row['Phrase'] = phrase
        new_row['Value'] = value
        expanded_rows.append(new_row)

# Create a new DataFrame from the expanded rows
expanded_df = pd.DataFrame(expanded_rows)

# %%
#expanded_df.to_csv('data_w_features_expanded.csv')

# %%
expanded_df = pd.read_csv('data_w_features_expanded.csv')

# %%
# Make sure each phrase to a string
expanded_df['Phrase'] = expanded_df['Phrase'].apply(lambda x: str(x))

# %%
# Function to extract features from each phrase/word such as
    # Difference between the original confidence score and the confidence score of the sentence when said phrase/word is removed
    # New label
    # New confidence score when phrase/word is removed
    # Whether or not the label switched when the phrase/word was removed
def get_confidence(row):
    sent_score = row['original_confidence']
    new_sent = row['Sentence']
    new_sent = new_sent.replace(row['Phrase'], "")
    results = sentiment_analyzer(new_sent)
    new_score = results[0]['score']
    new_label = results[0]['label']
    
    row['new_confidence_score'] = new_score
    row['new_confidence_label'] = new_label
    row['confidence_difference'] = sent_score - new_score
    if new_label == row['original_label']:
        row['switched'] = 0
    else:
        row['switched'] = 1
    print(row['Unnamed: 0'])
    return row

# %%
# Extract new features from each phrase
expanded_df = expanded_df.apply(lambda x: get_confidence(x), axis=1)

# %%
expanded_df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Sentence', 'Sentence Encodings',
#        'Phrases', 'Values', 'word_number', 'mean_confidence_difference',
#        'max_confidence_difference', 'min_confidence_difference',
#        'range_confidence_difference', 'std_confidence_difference',
#        'mean_confidence', 'max_confidence', 'min_confidence',
#        'range_confidence', 'std_confidence', 'original_confidence',
#        'original_label', 'amount_label_switched', 'above_0.05', 'above_0.1',
#        'above_0.2', 'above_0.3', 'below_-0.05', 'below_-0.1', 'below_-0.2',
#        'below_-0.3', 'between_+-0.05', 'Phrase', 'Value',
#        'new_confidence_score', 'new_confidence_label', 'confidence_difference',
#        'switched'],
#       dtype='object')

# %%
# Mapping to turn string data into ints
label_mapping = {'POS' : 0, 'NEG' : 1, 'NEU' : 2}

expanded_df['original_label'] = expanded_df['original_label'].apply(lambda x: label_mapping[x])
expanded_df['new_confidence_label'] = expanded_df['new_confidence_label'].apply(lambda x: label_mapping[x])

# %%
#expanded_df.to_csv('data_w_features_expanded.csv')

# %% [markdown]
# ### Part of Speech for Each Word & Phrase

# %%
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize

# Download the required resources
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')

# %%
# Function to find the POS of each word/word in each phrase
def part_of_speech_generator(row):
    
    # Tokenize the sentence in the 'Phrase' column of the row
    tokens = word_tokenize(row['Phrase'])
    
    # Generate POS tags for each token
    tagged_words = pos_tag(tokens)
    
    # Extract the POS tags using list comprehension
    row['POS_list'] = [word[1] for word in tagged_words]
    
    return row

# %%
# Clean the DataFrame 'Phrase' column
expanded_df['Phrase'] = expanded_df['Phrase'].fillna('').astype(str)

# Apply the part_of_speech_generator function to each row of the DataFrame
expanded_df = expanded_df.apply(part_of_speech_generator, axis=1)

# %%
# Flatten all lists in the 'POS' column into a single list
flattened_list = [pos_tag for sublist in expanded_df['POS_list'] for pos_tag in sublist]

# Convert the flattened list into a set to get unique POS tags
unique_pos_tags = set(flattened_list)

print(unique_pos_tags)
# Out:
# {',', 'JJ', 'PRP', 'RBR', 'VBZ', 'FW', '(', 'EX', ')', '.', 'VBG', 'MD', 'POS', 'PRP$', 'WP', 'NNS', 'CD', 'IN', 'NNPS', 'WRB', 'JJS', 'VBN', 'VB', 'RB', 'NN', 'TO', 'DT', 'CC', 'VBP', '$', "''", 'RBS', 'JJR', 'VBD', 'NNP', 'WDT', 'PDT', '``', ':'}

# %%
# Elements to remove
elements_to_remove = {',', '(', ')', '``', ':', '$', "''"}

# Remove multiple elements using difference_update
unique_pos_tags.difference_update(elements_to_remove)

print(unique_pos_tags)
# Out:
# {'JJ', 'PRP', 'RBR', 'VBZ', 'FW', 'EX', '.', 'VBG', 'MD', 'POS', 'PRP$', 'WP', 'NNS', 'CD', 'IN', 'NNPS', 'WRB', 'JJS', 'VBN', 'VB', 'RB', 'NN', 'TO', 'DT', 'CC', 'VBP', 'RBS', 'JJR', 'VBD', 'NNP', 'WDT', 'PDT'}

# %%
# Function used to one hot encode the POS for each phrase/word
def check_pos(row, pos):
    if pos in row['POS_list']:
        row[pos] = 1
    else:
        row[pos] = 0
    return row

# %%
# One hot encode each POS for each phrase
for pos in unique_pos_tags:
    expanded_df = expanded_df.apply(lambda x: check_pos(x, pos), axis=1)

# %% [markdown]
# # Model Training

# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from transformers import pipeline

# Define sentiment analyser model
sentiment_analyzer = pipeline("sentiment-analysis", model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0

# %%
expanded_df = pd.read_csv('data_w_features_expanded.csv')

# %%
# Shuffle df to get rid of any influence on the model from the ordering of sentences
shuffled_df = expanded_df.sample(frac=1).reset_index(drop=True)

# %%
# Create list of feature columns
features = ['word_number', 'mean_confidence_difference',
       'max_confidence_difference', 'min_confidence_difference',
       'range_confidence_difference', 'std_confidence_difference',
       'mean_confidence', 'max_confidence', 'min_confidence',
       'range_confidence', 'std_confidence', 'original_confidence',
       'original_label', 'amount_label_switched', 'above_0.05', 'above_0.1',
       'above_0.2', 'above_0.3', 'below_-0.05', 'below_-0.1', 'below_-0.2',
       'below_-0.3', 'between_+-0.05',
       'new_confidence_score', 'new_confidence_label', 'confidence_difference',
       'switched', 'POS', 'JJ', 'PRP',
       'RBR', 'VBZ', 'FW', 'EX', '.', 'VBG', 'MD', 'PRP$', 'WP', 'NNS', 'CD',
       'IN', 'NNPS', 'WRB', 'JJS', 'VBN', 'VB', 'RB', 'NN', 'TO', 'DT', 'CC',
       'VBP', 'RBS', 'JJR', 'VBD', 'NNP', 'WDT', 'PDT']

# %%
# Define feature df and label df
x = shuffled_df[features]
y = shuffled_df['Value']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
# Split dfs for training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Define a Scaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both the training and test data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define a logistic regression model
model = LogisticRegression()

# Train the model using the scaled training data
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score, classification_report, f1_score

# Define predictions for each word/phrase as being important to the sentiment or not
y_prob = model.predict_proba(X_test_scaled)[:, 1]


best_threshold = 0.0
best_f1 = 0.0  # Initialize to keep track of the highest F1 score
best_accuracy = 0.0  # To store the accuracy corresponding to the best F1 score
best_report = ""  # To store the classification report corresponding to the best F1 score

# Loop through thresholds from 0.0 to 1.0 with a step of 0.01
for threshold in range(0, 101):
    threshold /= 100  # Convert to float between 0.0 and 1.0

    y_pred_custom = (y_prob >= threshold).astype(int)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred_custom)
    report = classification_report(y_test, y_pred_custom, output_dict=True)
    
    # Extract F1 score for class 1
    f1_class_1 = report['1']['f1-score']

    # Check if the current F1 score is the highest
    if f1_class_1 > best_f1:
        best_f1 = f1_class_1
        best_threshold = threshold
        best_accuracy = accuracy
        best_report = classification_report(y_test, y_pred_custom)

# Print the best threshold and corresponding metrics
print(f"Best Threshold: {best_threshold}")
print(f"Accuracy at Best Threshold: {best_accuracy:.4f}")
print(f"F1 Score for Class 1 at Best Threshold: {best_f1:.4f}")
print(best_report)
# Out:
# Best Threshold: 0.41
# Accuracy at Best Threshold: 0.8220
# F1 Score for Class 1 at Best Threshold: 0.5887
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.89       432
#            1       0.68      0.52      0.59       141
#
#     accuracy                           0.82       573
#    macro avg       0.77      0.72      0.74       573
# weighted avg       0.81      0.82      0.81       573

# %%
# Get the coefficients of the model
coefficients = model.coef_[0]

# Create a DataFrame to view the feature importance more clearly
feature_importance = pd.DataFrame({
    'Feature': x.columns,
    'Coefficient': coefficients
})

# Sort the features by the absolute value of their coefficient
feature_importance['Absolute Coefficient'] = feature_importance['Coefficient'].abs()
feature_importance.sort_values(by='Absolute Coefficient', ascending=False, inplace=True)

print(feature_importance)
# Out:
#                         Feature  Coefficient  Absolute Coefficient
# 26                     switched     0.968311              0.968311
# 29                          PRP    -0.891549              0.891549
# 25        confidence_difference     0.500795              0.500795
# 48                           NN     0.487481              0.487481
# 12               original_label     0.446260              0.446260
# 24         new_confidence_label    -0.428841              0.428841
# 45                          VBN     0.368012              0.368012
# 47                           RB     0.354162              0.354162
# 21                   below_-0.3     0.345858              0.345858
# 28                           JJ     0.308801              0.308801
# 18                  below_-0.05     0.294600              0.294600
# 3     min_confidence_difference     0.284242              0.284242
# 35                          VBG     0.281971              0.281971
# 57                          WDT    -0.281383              0.281383
# 44                          JJS     0.275893              0.275893
# 22               between_+-0.05     0.252749              0.252749
# 0                   word_number    -0.236422              0.236422
# 16                    above_0.2    -0.215176              0.215176
# 14                   above_0.05     0.209302              0.209302
# 6               mean_confidence     0.204620              0.204620
# 38                           WP    -0.192718              0.192718
# 11          original_confidence     0.192690              0.192690
# 13        amount_label_switched    -0.158842              0.158842
# 55                          VBD     0.144876              0.144876
# 33                           EX    -0.143882              0.143882
# 39                          NNS     0.133527              0.133527
# 8                min_confidence     0.124210              0.124210
# 19                   below_-0.1    -0.119832              0.119832
# 4   range_confidence_difference    -0.119569              0.119569
# 9              range_confidence    -0.119569              0.119569
# 46                           VB     0.111090              0.111090
# 36                           MD     0.110839              0.110839
# 54                          JJR     0.108420              0.108420
# 58                          PDT    -0.092395              0.092395
# 49                           TO     0.089743              0.089743
# 23         new_confidence_score    -0.089385              0.089385
# 10               std_confidence     0.086549              0.086549
# 5     std_confidence_difference     0.086549              0.086549
# 42                         NNPS    -0.083676              0.083676
# 32                           FW    -0.077606              0.077606
# 34                            .    -0.075013              0.075013
# 41                           IN    -0.066577              0.066577
# 7                max_confidence     0.066360              0.066360
# 20                   below_-0.2     0.064608              0.064608
# 27                          POS    -0.060608              0.060608
# 50                           DT     0.060036              0.060036
# 40                           CD     0.056026              0.056026
# 51                           CC    -0.054250              0.054250
# 2     max_confidence_difference     0.053412              0.053412
# 56                          NNP    -0.050135              0.050135
# 37                         PRP$     0.047569              0.047569
# 30                          RBR     0.047542              0.047542
# 15                    above_0.1    -0.046826              0.046826
# 52                          VBP     0.043024              0.043024
# 31                          VBZ     0.039051              0.039051
# 53                          RBS     0.023283              0.023283
# 1    mean_confidence_difference     0.022036              0.022036
# 43                          WRB    -0.017675              0.017675
# 17                    above_0.3     0.015967              0.015967

# %% [markdown]
# ## (FAILED- Might Utilize with More Training Data) Threshold Predictor Usinge Linear Regression

# %%
predictions = pd.DataFrame(y_prob)

# %%
shuffled_df['predictions'] = predictions

# %%
from sklearn.metrics import f1_score
import numpy as np

def find_optimal_threshold_for_f1(subset, predictions_column):
    best_threshold = 0.1  # Start with a default threshold of 0.1
    best_f1 = 0  # Track the best overall F1 score

    thresholds = np.arange(0, 1.01, 0.01)  # Thresholds from 0 to 1 in steps of 0.01
    for threshold in thresholds:
        predictions = (subset[predictions_column] >= threshold).astype(int)
        f1 = f1_score(subset['Value'], predictions, average='macro')  # Calculate F1 score
        if f1 > best_f1:
            best_f1 = f1
            best_threshold = threshold
            
    return best_threshold, best_f1

# %%
# Find the threshold that optimizes the f1 score for each sentence
for sentence in shuffled_df['Sentence'].unique():
    subset = shuffled_df[shuffled_df['Sentence'] == sentence]
    threshold, f1 = find_optimal_threshold(subset, 'predictions')
    shuffled_df.loc[shuffled_df['Sentence'] == sentence, 'Optimal_Threshold'] = threshold
    shuffled_df.loc[shuffled_df['Sentence'] == sentence, 'Best_f1'] = f1

# %%
shuffled_df.sort_values(by='Sentence')['Best_f1'].unique()
# Out:
# array([0.62820513, 0.5       , 0.54444444, 0.58152174, 0.62592593,
#        0.61083744, 0.68478261, 0.5877193 , 0.57142857, 0.56666667,
#        0.6       , 0.66666667, 0.51052632, 0.66296296, 0.53282828,
#        0.58333333, 0.55384615, 0.75      , 0.72222222, 0.54511278,
#        0.54166667, 0.58198381, 0.57619048, 0.57236842, 0.58653846,
#        0.53571429, 0.55111111, 0.60606061, 0.55555556, 0.93181818,
#        0.63636364, 0.55529954, 0.55387205, 0.6372549 , 0.63333333,
#        0.66883117, 0.56149733, 0.60902256, 0.6659919 , 0.65      ,
#        0.63387097, 0.57894737, 0.52545455, 0.57222222, 0.58730159,
#        0.60833333, 0.64642857, 0.59285714, 0.72058824, 0.58516484,
#        0.57368421, 0.54040404])

# %%
# Define feature columns
features_threshold_cols = ['word_number',
       'mean_confidence_difference', 'max_confidence_difference',
       'min_confidence_difference', 'range_confidence_difference',
       'std_confidence_difference', 'mean_confidence', 'max_confidence',
       'min_confidence', 'range_confidence', 'std_confidence',
       'original_confidence', 'original_label', 'amount_label_switched',
       'above_0.05', 'above_0.1', 'above_0.2', 'above_0.3', 'below_-0.05',
       'below_-0.1', 'below_-0.2', 'below_-0.3', 'between_+-0.05']

# %%
# Combine feature columns and label column
sentence_df = pd.concat([shuffled_df[features_threshold_cols], shuffled_df['Optimal_Threshold']], axis=1)

# %%
# Drop duplicates
sentence_df = sentence_df.drop_duplicates()

# %%
# Create feature df and label df
features_threshold_X = sentence_df[features_threshold_cols]
features_threshold_y = sentence_df['Optimal_Threshold']

# %%
from sklearn.feature_selection import mutual_info_regression

mi_scores = mutual_info_regression(features_threshold_X, features_threshold_y)

mi_scores_df = pd.DataFrame({
    'Feature': features_threshold_X.columns,
    'Mutual Information Score': mi_scores
}).sort_values(by='Mutual Information Score', ascending=False)

train_cols = list(mi_scores_df['Feature'])
print(mi_scores_df)
# Out:
#                         Feature  Mutual Information Score
# 8                min_confidence                  0.105349
# 20                   below_-0.2                  0.093282
# 16                    above_0.2                  0.074062
# 11          original_confidence                  0.060861
# 2     max_confidence_difference                  0.056648
# 6               mean_confidence                  0.036496
# 15                    above_0.1                  0.018154
# 4   range_confidence_difference                  0.008981
# 9              range_confidence                  0.008981
# 7                max_confidence                  0.007976
# 13        amount_label_switched                  0.003259
# 21                   below_-0.3                  0.000000
# 19                   below_-0.1                  0.000000
# 18                  below_-0.05                  0.000000
# 17                    above_0.3                  0.000000
# 0                   word_number                  0.000000
# 14                   above_0.05                  0.000000
# 12               original_label                  0.000000
# 1    mean_confidence_difference                  0.000000
# 10               std_confidence                  0.000000
# 5     std_confidence_difference                  0.000000
# 3     min_confidence_difference                  0.000000
# 22               between_+-0.05                  0.000000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

for i in range(1, len(train_cols)):
    
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(features_threshold_X[train_cols[0:i]], features_threshold_y, test_size=0.2, random_state=42)

    scaler = StandardScaler()

    # Fit the scaler on the training data and transform both the training and test data
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    # Initialize the Linear Regression model
    model = LinearRegression()

    # Fit the model to the training data
    model.fit(X_train, y_train)

    # Predict on the test set
    y_pred = model.predict(X_test)

    print(f"Number of cols: {i}")
    
    # Calculate Mean Squared Error
    mse = mean_squared_error(y_test, y_pred)
    print(f"Mean Squared Error: {mse:.2f}")

    # Calculate R-squared
    r2 = r2_score(y_test, y_pred)
    print(f"R-squared: {r2:.2f}")
    
    print('')
# Out:
# Number of cols: 1
# Mean Squared Error: 0.08
# R-squared: -0.16
#
# Number of cols: 2
# Mean Squared Error: 0.08
# R-squared: -0.21
#
# Number of cols: 3
# Mean Squared Error: 0.08
# R-squared: -0.13
#
# Number of cols: 4
# Mean Squared Error: 0.08
# R-squared: -0.12
#
# Number of cols: 5
# Mean Squared Error: 0.08
# R-squared: -0.13
#
# Number of cols: 6
# Mean Squared Error: 0.07
# R-squared: -0.08
#
# Number of cols: 7
# Mean Squared Error: 0.08
# R-squared: -0.13
#
# Number of cols: 8
# Mean Squared Error: 0.08
# R-squared: -0.22
#
# Number of cols: 9
# Mean Squared Error: 0.08
# R-squared: -0.22
#
# Number of cols: 10
# Mean Squared Error: 0.07
# R-squared: -0.11
#
# Number of cols: 11
# Mean Squared Error: 0.08
# R-squared: -0.13
#
# Number of cols: 12
# Mean Squared Error: 0.07
# R-squared: -0.08
#
# Number of cols: 13
# Mean Squared Error: 0.06
# R-squared: 0.08
#
# Number of cols: 14
# Mean Squared Error: 0.06
# R-squared: 0.05
#
# Number of cols: 15
# Mean Squared Error: 0.06
# R-squared: 0.06
#
# Number of cols: 16
# Mean Squared Error: 0.07
# R-squared: 0.03
#
# Number of cols: 17
# Mean Squared Error: 0.06
# R-squared: 0.10
#
# Number of cols: 18
# Mean Squared Error: 0.05
# R-squared: 0.22
#
# Number of cols: 19
# Mean Squared Error: 0.05
# R-squared: 0.22
#
# Number of cols: 20
# Mean Squared Error: 0.05
# R-squared: 0.23
#
# Number of cols: 21
# Mean Squared Error: 0.05
# R-squared: 0.23
#
# Number of cols: 22
# Mean Squared Error: 0.05
# R-squared: 0.23

# %% [markdown]
# # Sentiment Analysis with Reasoning - Application of Model

# %%
import spacy
import nltk
from spacy.matcher import Matcher

nlp = spacy.load('en_core_web_sm')

def extract_phrases(text):
    doc = nlp(text)
    phrases = set()

    # Extract noun chunks
    for chunk in doc.noun_chunks:
        phrases.add(chunk.text)
    
    # Extract verb phrases using dependency parsing
    for token in doc:
        if token.pos_ == 'VERB':
            verb_phrase = ' '.join([child.text for child in token.children if child.dep_ in {'aux', 'neg', 'advmod'}] + [token.text])
            phrases.add(verb_phrase)
    
    # Extract additional phrases using patterns
    matcher = Matcher(nlp.vocab)
    patterns = [
        [{"POS": "ADJ"}, {"POS": "NOUN"}],  # Adjective + Noun
        [{"POS": "NOUN"}, {"POS": "NOUN"}],  # Noun + Noun
        [{"POS": "ADV"}, {"POS": "VERB"}],   # Adverb + Verb
    ]
    matcher.add("PhrasePatterns", patterns)
    
    matches = matcher(doc)
    for match_id, start, end in matches:
        span = doc[start:end]
        phrases.add(span.text)

    return list(phrases)

def part_of_speech_generator(phrase, phrase_dict):
    
    tokens = word_tokenize(phrase)
    
    # Generate POS tags for each token
    tagged_words = pos_tag(tokens)
    
    # Extract the POS tags using list comprehension
    return [word[1] for word in tagged_words]
    
    
# Extract statistical features for each sentence
def get_features_sentence(sentence, phrases):
    row = {}
    differences = []
    confidence_scores = []
    amount_change = 0
    
    sent_results = sentiment_analyzer(sentence)
    sent_label = sent_results[0]['label']
    sent_score = sent_results[0]['score']
    
    above_0_05 = 0
    above_0_1 = 0
    above_0_2 = 0
    above_0_3 = 0
    
    below_0_05 = 0
    below_0_1 = 0
    below_0_2 = 0
    below_0_3 = 0
    
    between_0_05  = 0
    
    phrase_dict = {}
    
    for phrase in phrases:
        
        phrase_dict[phrase] = part_of_speech_generator(phrase, phrase_dict)
        
        new_sent = sentence
        new_sent = new_sent.replace(phrase, "")
        results = sentiment_analyzer(new_sent)
        new_score = results[0]['score']
        new_label = results[0]['label']
        difference = sent_score - new_score
        if new_label == sent_label:
            differences.append((sent_score - new_score))
            confidence_scores.append(new_score)
        else:
            amount_change += 1
            
        if difference > 0.3:
            above_0_3 += 1
        elif difference > 0.2:
            above_0_2 += 1
        elif difference > 0.1:
            above_0_1 += 1
        elif difference > 0.05:
            above_0_05 += 1
        elif difference < -0.3:
            below_0_3 += 1
        elif difference < -0.2:
            below_0_2 += 1
        elif difference < -0.1:
            below_0_1 += 1
        elif difference < -0.05:
            below_0_05 += 1
        else:
            between_0_05 += 1
                    
    num_words = len(sentence.split(' '))
    
    row['word_number'] = [num_words]
    row['mean_confidence_difference'] = [statistics.mean(differences) if differences else 0]
    row['max_confidence_difference'] = [max(differences) if differences else 0]
    row['min_confidence_difference'] = [min(differences) if differences else 0]
    row['range_confidence_difference'] = [(max(differences) - min(differences)) if differences else 0]
    row['std_confidence_difference'] = [statistics.stdev(differences) if len(differences) > 1 else 0]
    
    row['mean_confidence'] = [statistics.mean(confidence_scores) if confidence_scores else 0]
    row['max_confidence'] = [max(confidence_scores) if confidence_scores else 0]
    row['min_confidence'] = [min(confidence_scores) if confidence_scores else 0]
    row['range_confidence'] = [(max(confidence_scores) - min(confidence_scores)) if confidence_scores else 0]
    row['std_confidence'] = [statistics.stdev(confidence_scores) if len(confidence_scores) > 1 else 0]
    
    row['original_confidence'] = [sent_score]
    row['original_label'] = [1 if sent_label == 'POS' else 0]
    
    row['amount_label_switched'] = [amount_change]
    
    row['above_0.05'] = [above_0_05]
    row['above_0.1'] = [above_0_1]
    row['above_0.2'] = [above_0_2]
    row['above_0.3'] = [above_0_3]
    row['below_-0.05'] = [below_0_05]
    row['below_-0.1'] = [below_0_1]
    row['below_-0.2'] = [below_0_2]
    row['below_-0.3'] = [below_0_3]
    row['between_+-0.05'] = [between_0_05]
    return row, phrase_dict

# Extract features for each phrase/words effect on confidence score and label
def get_confidence(sentence, original_confidence, original_confidence_label, phrase_df, phrase):
    sent_score = original_confidence
    new_sent = sentence
    new_sent = new_sent.replace(phrase, "")
    results = sentiment_analyzer(new_sent)
    new_score = results[0]['score']
    new_label = results[0]['label']
    
    phrase_df['new_confidence_score'] = new_score
    phrase_df['new_confidence_label'] = [
        1 if new_label == 'POS' else 2 if new_label == 'NEG' else 0
    ]
    phrase_df['confidence_difference'] = sent_score - new_score
    if new_label == original_confidence_label:
        phrase_df['switched'] = 0
    else:
        phrase_df['switched'] = 1
    return phrase_df

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))


pos_tags = ['POS', 'JJ', 'PRP', 'RBR', 'VBZ', 'FW', 'EX', '.', 'VBG', 'MD', 'PRP$', 'WP',
       'NNS', 'CD', 'IN', 'NNPS', 'WRB', 'JJS', 'VBN', 'VB', 'RB', 'NN', 'TO',
       'DT', 'CC', 'VBP', 'RBS', 'JJR', 'VBD', 'NNP', 'WDT', 'PDT']

# Function that gives the sentiment of each sentence along with an explanation of the words 
# important to its sentiment using the model
def generate_explanation(sentence):
    sent_results = sentiment_analyzer(sentence)
    sent_label = sent_results[0]['label']
    sent_score = sent_results[0]['score']

    phrases = extract_phrases(sentence)
    words = sentence.split(' ')
    
    for word in words:
        if (word not in phrases) and (word.lower() not in stop_words):
            phrases.append(word)
    
    features, phrase_dict = get_features_sentence(sentence, phrases)
    
    important = ''
    amount = 0
    for phrase in phrases:
        phrase_df = pd.DataFrame(features)
        
        phrase_df = get_confidence(sentence, sent_score, sent_label, phrase_df, phrase)
        
        for pos in pos_tags:
            if pos in phrase_dict[phrase]:
                phrase_df[pos] = 1
            else:
                phrase_df[pos] = 0

        phrase_df_scaled = scaler.transform(phrase_df)
        
        
        pred = model.predict_proba(phrase_df_scaled)[:, 1]
        
        if pred >= 0.41:
            amount += 1
            important += '"'
            important += phrase
            important += '," '
        
    important = important[:-3] + important[-3 + 1:]
    important = important[:-1]
    if amount >= 2:
        important = important.split(" ")
        important.insert(len(important) + -1, 'and')
        important = " ".join(important)
        sing_plur = 'words/phrases'
    else:
        sing_plur = 'word/phrase'
            
    label_mapping = {'NEU' : 'neutral', 'POS' : 'positive', 'NEG' : 'negative'}
    explanation = f"This sentence is {label_mapping[sent_label]} because it contains the {sing_plur} {important}."
    return explanation
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\17028\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\17028\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
new_sentences = pd.read_csv('pos_neg_sentences.csv')

# %%
sentence_list = list(new_sentences['Sentence'][100:500])

# %%
# Print the sentiment and important phrases/words for each sentence in sentence_list
for sentence in sentence_list:
    print(sentence)
    print("")
    explanation = generate_explanation(sentence)
    print(explanation)
    print("_____________________________________")
    print("")
# Out:
# The best AI image generator if you have a reference photo you'd like for the AI image generator to use as inspiration in either structure or style when rendering a new image.
#
# This sentence is positive because it contains the words/phrases "a reference photo," "new image," "a new image," "The best AI image generator," and "best".
# _____________________________________
#
# “Today, I am fired up to endorse Kamala Harris for President of the United States,” Whitmer wrote in a statement.
#
# This sentence is positive because it contains the word/phrase "fired".
# _____________________________________
#
# And OpenAI has made a lot of advancements since then. For example: The paid version of ChatGPT includes capabilities for web search with real-time info in partnership with Bing, and plug-ins for travel companies allow users to access information about flights and more.
#
# This sentence is positive because it contains the words/phrases "has made," "The paid version," "advancements," "real-time info," and "made".
# _____________________________________
#
# Hearst Television participates in various affiliate marketing programs, which means we may get paid commissions on editorially chosen products purchased through our links to retailer sites.
#
# This sentence is positive because it contains the words/phrases "editorially chosen products," "means," "various affiliate marketing programs," "editorially chosen," "get," and "paid".
# _____________________________________
#
# Includes unlimited access to WSJ's unrivaled journalism.
#
# This sentence is positive because it contains the words/phrases "unlimited access," "unrivaled journalism," "WSJ's unrivaled journalism," "access," and "unrivaled".
# _____________________________________
#
# The National Aeronautics and Space Administration (NASA) has released stunning pictures of the cosmos. As per NASA, the pictures were captured by NASA Webb and NASA Chandra Xray.
#
# This sentence is positive because it contains the words/phrases "has released," "stunning pictures," "captured," "released," "stunning," and "pictures".
# _____________________________________
#
# LADIES AND GENTLEMEN, AMBASSADOR CHAIRMAN OF THE UNITED STATES. [APPLAUSE]
#
# This sentence is positive because it contains the words/phrases "GENTLEMEN," "LADIES," "AMBASSADOR CHAIRMAN," "GENTLEMEN,," "AMBASSADOR," and "STATES.".
# _____________________________________
#
# "The way that Russia is now governed by Putin is not a proper regime in the sense of it's not organised in any way except you have to do what Putin is telling you."
#
# This sentence is negative because it contains the words/phrases "that now governed," "proper regime," "now governed," "a proper regime," "not organised," and "proper".
# _____________________________________
#
# As for why those inside Russia had not protested, she said: "People inside of Russia are very... scared to say anything. It's like Stockholm syndrome, they are just trying to live their life.
#
# This sentence is negative because it contains the words/phrases "why had not protested," and "scared".
# _____________________________________
#
# “Our president, Joe Biden, wanted to be here today. He is feeling much better and recovering fast, and he looks forward to getting back on the road,” Harris, 59, told the student athletes — before launching into a political eulogy for her boss.
#
# This sentence is positive because it contains the words/phrases "a political eulogy," "fast recovering," "student athletes," "is feeling," "the student athletes," "forward looks," "launching," "Our president," "back getting," "political eulogy," "her boss," "feeling," "better," "recovering," "fast,," "forward," "getting," and "back".
# _____________________________________
#
# Dmitry Sergienko, who cast his ballot in Moscow, said, “I am happy with everything and want everything to continue as it is now.”
#
# This sentence is positive because it contains the words/phrases "to continue," "happy," "continue," and "now.”".
# _____________________________________
#
# Delta had more than 400 cancellations, not specific to Detroit, by 9 a.m. Tuesday and in the time since the outage had canceled more flights than it canceled for half of 2023, USA Today reported.
#
# This sentence is negative because it contains the words/phrases "more than 400 cancellations," and "canceled".
# _____________________________________
#
# Says the guy who’s constantly bashing Netanyahu.
#
# This sentence is negative because it contains the words/phrases "constantly bashing," "’s constantly and bashing".
# _____________________________________
#
# Questions about Biden exploded after his poor debate performance against former President Donald Trump on June 27. Party leaders worried Biden's lagging poll performance and place at the top of the Democratic ticket would hamper Democrats farther down the ballot.
#
# This sentence is negative because it contains the words/phrases "his poor debate performance," "poor debate," and "poor".
# _____________________________________
#
# China's President Xi Jinping joined North Korean leader Kim Jong Un - whose regime has supplied weapons to Russia in its war in Ukraine - in congratulating the Russian president.
#
# This sentence is positive because it contains the words/phrases "joined," "China's President Xi Jinping," "North Korean leader Kim Jong Un," "congratulating," "Korean leader," and "whose".
# _____________________________________
#
# California just voted unanimously to nominate our very own @KamalaHarris for President. Our delegates have put the VP over the required number she needs to be our nominee going into convention!
#
# This sentence is positive because it contains the words/phrases "just voted," "our very own @KamalaHarris," "just unanimously voted," "own @KamalaHarris," and "unanimously".
# _____________________________________
#
# According to Czajkowski, ChatGPT 4's recommendations were varied and included a solid list of restaurants worth visiting, like Fox in the Snow Cafe or The Pearl. It also included attractions like the Columbus Zoo and Aquarium, a destination often missing from the free AI chatbot lists.
#
# This sentence is positive because it contains the words/phrases "a solid list," "the free AI chatbot lists," "solid list," "ChatGPT 4's recommendations," "a destination," "visiting," "solid," "list," "worth," "visiting,," and "often".
# _____________________________________
#
# Speaking while in the Georgian capital Tbilisi as part of a three-day tour of the South Caucasus, Jens Stoltenberg said Russia's election was "clearly neither free nor fair".
#
# This sentence is negative because it contains the words/phrases "neither," and "fair".".
# _____________________________________
#
# Delta Air Lines is under federal investigation over how it's been handling delays and cancellations amid technical issues with its crew scheduling software.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# Murati was a perfect choice to lead the event. In her casual jeans and perfect blowout, she exuded trust and confidence, breezing through the ethics and safety concerns with an assuring yet vague disclaimer:
#
# This sentence is positive because it contains the words/phrases "an assuring yet vague disclaimer," "perfect choice," "a perfect choice," "exuded," "her casual jeans," "vague disclaimer," "to lead," and "perfect".
# _____________________________________
#
# Pennsylvania’s Democratic voting delegates unanimously endorsed Kamala Harris for president in a Monday meeting, according to a Democratic source present at the meeting.
#
# This sentence is positive because it contains the words/phrases "unanimously endorsed," "Kamala Harris," "Pennsylvania’s Democratic voting delegates," and "endorsed".
# _____________________________________
#
# “While the evidence is often clear and convincing, many Title VI investigations have remained unresolved for months, and even years,” Gottheimer wrote.
#
# This sentence is negative because it contains the words/phrases "many Title VI investigations," "months," "Title," "investigations," "months,," and "years,”".
# _____________________________________
#
# E. Coli: The bacteria, which has recently been found in ground beef and walnuts, sickens an estimated 265,000 Americans each year.
# This sentence is negative because it contains the words/phrases "sickens," "has recently and found".
# _____________________________________
#
# By contrast, the new system can operate directly in speech without needing to lean on other models to prop it up, speeding up responses and allowing it to acknowledge quirks such as tone of voice.
#
# This sentence is positive because it contains the words/phrases "allowing," "needing," "the new system," "responses," "speeding," "new," "lean," "models," and "up,".
# _____________________________________
#
# Listeria is especially dangerous to women who are pregnant, people 65 and older and those with weakened immune systems. The CDC says people in those categories should not eat meat sliced at any deli counter unless it is reheated to an internal temperature of 165 degrees Fahrenheit.
#
# This sentence is negative because it contains the word/phrase "should not counter eat".
# _____________________________________
#
# Beyond the fact that voters had virtually no choice, independent monitoring of the election was extremely limited.
#
# This sentence is negative because it contains the words/phrases "the election," "independent monitoring," "virtually no choice," "fact," "choice,," "independent," "election," and "extremely".
# _____________________________________
#
# “No billionaire should pay a lower federal tax rate than a teacher, a sanitation worker or a nurse,” he said.
#
# This sentence is negative because it contains the words/phrases "should pay," and "pay".
# _____________________________________
#
# Listeria typically spreads to people through contaminated food or water but can also be transmitted from mother to fetus.
#
# This sentence is negative because it contains the word/phrase "contaminated food".
# _____________________________________
#
# “I want to do what [Alexei] thought was right, and I urge everyone to come to his memory,” she said in a video. “This will be your personal contribution to the common cause. There are probably many people close to you who are against Putin and against the war.”
#
# This sentence is positive because it contains the words/phrases "the common cause," "your personal and contribution".
# _____________________________________
#
# "I think it's super unhelpful to engage in any hypotheticals," added the Governor.
#
# This sentence is negative because it contains the word/phrase "unhelpful".
# _____________________________________
#
# President Joe Biden condemned the “ferocious surge of antisemitism in America and around the world” during a Tuesday ceremony to remember Holocaust victims at a time when the controversy over the war in Gaza has sparked new waves of violence and hateful rhetoric toward Jews.
#
# This sentence is negative because it contains the word/phrase "“ferocious".
# _____________________________________
#
# “The blood is on your hands, Biden, we can see it all,” the rapper says in the song.
#
# This sentence is negative because it contains the words/phrases "your hands," "The blood," "blood," and "see".
# _____________________________________
#
# President Joe Biden condemned the surge of antisemitism in America and around the world during a Tuesday ceremony to remember victims of the Holocaust and warned too many are ‘forgetting’ the horrors unleashed on Israel by Hamas on Oct. 7, 2023.
#
# This sentence is negative because it contains the words/phrases "the horrors," "warned," and "horrors".
# _____________________________________
#
# "We developed the Privacy Sandbox with the goal of finding innovative solutions that meaningfully improve online privacy while preserving an ad-supported internet that supports a vibrant ecosystem of publishers, connects businesses with customers, and offers all of us free access to a wide range of content," Chavez wrote.
#
# This sentence is positive because it contains the words/phrases "supported," "the goal," "innovative solutions," "a wide range," "vibrant ecosystem," "wide range," "preserving," "free access," "meaningfully improve," "finding," "an ad-supported internet," "a vibrant ecosystem," "meaningfully," and "vibrant".
# _____________________________________
#
# Listeria infections are especially dangerous for people older than 65 and those with weakened immune systems, according to the CDC. Victims of this outbreak ranged in age from 32 to 94, with a median age of 75.
#
# This sentence is negative because it contains the word/phrase "weakened immune systems".
# _____________________________________
#
# Arizona Sen. Mark Kelly has more authority to speak on migration issues — a big plus as Republicans attack Harris over the border. | Manuel Balce Ceneta/AP
#
# This sentence is positive because it contains the word/phrase "big".
# _____________________________________
#
# Least walkable cities in the U.S.
#
# This sentence is negative because it contains the words/phrases "Least walkable cities," "walkable cities," "Least," and "U.S.".
# _____________________________________
#
# “I don’t think he had any regard for the rest of us or for the country overall, and I say that as a former Republican,” the veteran, identified as Joe, says about Trump. “I have tremendous fear that he could be elected again.”
#
# This sentence is negative because it contains the word/phrase "fear".
# _____________________________________
#
# Outside of work, you’ll catch him streaming almost every new movie and TV show release as soon as it's available.
#
# This sentence is positive because it contains the words/phrases "’ll soon catch," "new movie," "almost every new movie and TV show release," "work,," "catch," "soon," and "available.".
# _____________________________________
#
# Less than two weeks after Shapiro took office as governor, he had to contend with a crisis when a train derailed in East Palestine, Ohio, less than a mile from Pennsylvania’s border, and released thousands of tons of toxic chemicals.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# "We're just helpless, really," Austinite and Delta customer Sarah Lindsey said. "And it's not moving. I've been saying the exact same place for the last probably 25-30 minutes at least."
#
# This sentence is negative because it contains the words/phrases "'s not moving," "'ve been saying," and "helpless,".
# _____________________________________
#
# The memo tries to blame Harris for illegal crossings at the US-Mexico border. Harris “is as bad, if not worse, than Joe Biden,” it argues.
#
# This sentence is negative because it contains the word/phrase "worse,".
# _____________________________________
#
# We used to talk about the iPhone moment when Steve Jobs changed the cellphone industry forever, and then in November 2022 we began to talk about the ChatGPT moment. This was another industry-defining product and I think OpenAI has done it again.
#
# This sentence is positive because it contains the words/phrases "another industry-defining product," "defining," "think," "when forever changed," "has again done," "the iPhone moment," "used," "the ChatGPT moment," "to talk," "OpenAI," "the cellphone industry," "then began," "talk," "moment," "changed," "industry," "forever,," "ChatGPT," "industry-defining," "product," "done," and "again.".
# _____________________________________
#
# Rollout of the new tool started immediately, with OpenAI saying, "capabilities will be rolled out iteratively (with extended red team access starting today)."
#
# This sentence is positive because it contains the words/phrases "new tool," "extended red team access," "OpenAI," "will iteratively rolled," "team access," "Rollout," "the new tool," "new," "started," "immediately,," ""capabilities," and "extended".
# _____________________________________
#
# But Delta says it will not reimburse for "other airline tickets, prepaid expenses, including hotels and activities at your destination, or lost wages."
#
# This sentence is negative because it contains the words/phrases "will not reimburse," and "reimburse".
# _____________________________________
#
# He described Jewish students facing harassment, and posters and slogans "calling for the annihilation of Israel" as well as efforts by some to deny what happened on Oct. 7.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# “If there was to be a Harris-Shapiro ticket and I think the message that they have would resonate in the important states like Wisconsin and Illinois and Michigan,” Costa said. “There’s similarities in the nature of those states and that will bring a lot of support to a national ticket.”
# This sentence is positive because it contains the words/phrases "a lot," "support," "will bring," "bring," and "lot".
# _____________________________________
#
# If you don’t understand what that means, you are both not alone and in a safe space. Welcome to “Bratology 101.”
#
# This sentence is positive because it contains the words/phrases "a safe space," "means," "safe space," and "safe".
# _____________________________________
#
# “I think we all support Vice President Harris,” he said. “I think when I look at it, both narratively and logistically, she’s the right fit for where we are.”
#
# This sentence is positive because it contains the words/phrases "narratively ’s," "right fit," "he," "the right fit," "support," "think," "narratively," "logistically,," "right," and "fit".
# _____________________________________
#
# High-quality renditions, four images per prompt, and fun expressive chip feature
#
# This sentence is positive because it contains the words/phrases "High-quality renditions," "expressive chip," "fun expressive chip feature," and "fun".
# _____________________________________
#
# With nearly 100% of all precincts counted, Putin received 87.29% of the vote, Central Election Commission chief Ella Pamfilova said. Nearly 76 million voters cast their ballots for Putin, his highest vote tally ever, Pamfilova said.
#
# This sentence is positive because it contains the words/phrases "Nearly 76 million voters," "vote tally," "nearly 100%," "highest vote," "ever cast," "his highest vote tally," "highest," "vote," and "ever,".
# _____________________________________
#
# “We’ve got everyone around the company working around the clock to get this operation where it needs to be,” Delta CEO Ed Bastian said in a video message to employees on Monday. “Keep taking great care of our customers and each other in the coming days.”
#
# This sentence is positive because it contains the words/phrases "great care," "’ve got," and "great".
# _____________________________________
#
# Biden and his aides have, since reports of verbal and physical attacks against Jewish students emerged months ago, denounced them — but have nevertheless been accused by many Republicans of remaining silent or actually encouraging antisemitic behavior.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# "I think he's a capable, talented, and an outstanding statewide leader and I do hope VP Harris will consider him," Coons said.
#
# This sentence is positive because it contains the words/phrases "will consider," "think," "statewide leader," "talented,," "outstanding," "statewide," "leader," "hope," and "VP".
# _____________________________________
#
# Pro-Palestine and Muslim American groups raised alarm over the decision, saying it could be unconstitutional and curtail free speech.
#
# This sentence is negative because it contains the word/phrase "unconstitutional and curtail free speech".
# _____________________________________
#
# NR Daily is delivered right to you every afternoon. No charge.
#
# This sentence is positive because it contains the words/phrases "No charge," "right," and "charge.".
# _____________________________________
#
# The interview drew Biden’s attention, prompting him to tell the audience in New Hampshire that cuts were off the table: “The bottom line is he’s still at it. I’m never going to allow that to happen.”
#
# This sentence is negative because it contains the words/phrases "’m never going," "never and going".
# _____________________________________
#
# The line to get into the event, which is taking place at a local high school, is enormous. It is unlikely that everyone in line will be allowed into the small performing arts auditorium in which the event is being held.
#
# This sentence is negative because it contains the words/phrases "to get," "The line," "line," "enormous.," and "allowed".
# _____________________________________
#
# As expected, Russian President Vladimir Putin has won his fifth term in office, following a campaign in which all his significant rivals were barred from running, imprisoned, or dead.
#
# This sentence is positive because it contains the words/phrases "has won," "fifth term," "expected," "imprisoned," "his fifth term," and "expected,".
# _____________________________________
#
# This election will quickly be forgotten. Rightly so because of its farcical nature. The war, however, will reverberate for decades to come, well beyond the end of hostilities and Putin’s lifetime, whether it ends naturally or violently."
#
# This sentence is negative because it contains the words/phrases "however will reverberate," "will quickly forgotten," and "forgotten.".
# _____________________________________
#
# “Putin called Navalny by name for the first time, a month after he cynically killed him,” said Leonid Volkov, who was Navalny’s chief of staff during his presidential run in 2018. “The bloodsucking bug revels in its impunity. It will burst soon and that will be some splash.”
#
# This sentence is negative because it contains the words/phrases "cynically killed," and "killed".
# _____________________________________
#
# Colorado's latest layer farm outbreak occurred not far from where culling workers were infected in a similar event.
#
# This sentence is negative because it contains the words/phrases "latest layer," "Colorado's latest layer farm and outbreak".
# _____________________________________
#
# In addition, if he does get his wish and raises the corporate-income-tax rate, he won’t raise the revenue he hopes to raise, and whatever he gets could eventually be shouldered by workers in the form of lower wages. The same can be said for the rest of his capital-income-taxing agenda.
#
# This sentence is negative because it contains the word/phrase "won’t".
# _____________________________________
#
# The most comprehensive solution to manage all your complex and ever-expanding tax and compliance needs.
#
# This sentence is positive because it contains the words/phrases "compliance needs," "The most comprehensive solution," "ever expanding," "comprehensive solution," "comprehensive," and "solution".
# _____________________________________
#
# Alphabet Inc.’s Google said it plans to give people who use its Chrome web browser the option to choose a more privacy-sensitive experience, rather than phasing out cookies, the software that lets marketers track users.
#
# This sentence is positive because it contains the words/phrases "to give," "Alphabet Inc.," "said," "people," "the option," "more privacy," "plans," "Alphabet," "give," "option," and "experience,".
# _____________________________________
#
# Pregnant people typically experience fever, fatigue and muscle aches, officials said. Listeria infection during pregnancy can lead to miscarriage, stillbirth, premature delivery or life-threatening infection of the newborn, according to officials.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# Google kept stalling as it struggled to appease both the digital ad community and government regulators.
#
# This sentence is negative because it contains the words/phrases "stalling," and "struggled".
# _____________________________________
#
# Google's intentions for Privacy Sandbox, which was meant to block third-party cookies, had trouble from the outset. A year after starting work on it, Google said that the initiative would have to be delayed since "more time is needed across the ecosystem to get this right."
#
# This sentence is negative because it contains the words/phrases "trouble," "had," "the outset," "more time," "cookies,," "outset.," "year," "delayed," and ""more".
# _____________________________________
#
# “I see your fear, your hurt, and your pain. Let me reassure you as your president: You are not alone. You belong. You always have and you always will,” he said.
#
# This sentence is positive because it contains the words/phrases "your fear," "fear,," "alone.," "always," and "will,”".
# _____________________________________
#
# However, the plan continued to be opposed by news websites. DMGT told the House of Lords this year that testing of Privacy Sandbox had reduced revenue by 31pc per 1,000 webpage visits.
#
# This sentence is negative because it contains the words/phrases "opposed," and "reduced".
# _____________________________________
#
# The deadly outbreak strain of Listeria was found across 12 states including the the Midwest and South. The majority of hospitalizations were centered in the Mid-Atlantic states including New York, Pennsylvania, New Jersey, Maryland and Virginia.
# This sentence is negative because it contains the words/phrases "The deadly outbreak strain," "deadly outbreak," and "deadly".
# _____________________________________
#
# On Tuesday, Biden condemned the protesters’ use of the word “intifada,” as well as the group of Columbia University students who illegally occupied and barricaded a campus building. Biden also alluded to the campus turmoil in his proclamation this week marking Jewish American Heritage Month.
#
# This sentence is negative because it contains the words/phrases "Columbia University students," and "condemned".
# _____________________________________
#
# The Kremlin has severely crippled the Russian opposition in recent years. Top figures are either in jail or in exile abroad, and the death last month of Alexei Navalny, who was Putin’s most vocal opponent, raised even more questions about what lies ahead for them.
#
# This sentence is negative because it contains the words/phrases "has severely crippled," "even more questions," "severely crippled," "Putin’s most vocal and opponent".
# _____________________________________
#
# Biden, in his remarks on Tuesday, is expected to discuss the rise in antisemitic incidents since the Oct. 7 attacks that left more than 1,000 Israelis dead, a White House official said.
#
# This sentence is negative because it contains the words/phrases "Oct.," "1,000," "Israelis," and "said.".
# _____________________________________
#
# The only member of the Colorado delegation to call for Biden to step down, Democratic Rep. Brittany Pettersen said Biden was a “true patriot who puts the interest of the country and the American people over himself.”
#
# This sentence is positive because it contains the words/phrases "a “true patriot," "true patriot," and "patriot".
# _____________________________________
#
# After weeks of turmoil over the future of the Democratic ticket, Kessler said the campaign donors he’s courted as a bundler for Biden’s campaign are turning their full attention to Harris and committing to work on her behalf. “They’re really excited, and they are all in,” he said.
#
# This sentence is positive because it contains the words/phrases "Democratic ticket," "full attention," "committing," "their full attention," "the Democratic ticket," "the campaign donors," "courted," "to work," "are turning," "really," and "excited,".
# _____________________________________
#
# “My commitment to the safety of the Jewish people, the security of Israel, and its right to exist as an independent Jewish state is ironclad, even when we disagree,” Biden said.
#
# This sentence is positive because it contains the words/phrases "the security," "an independent Jewish state," "Jewish people," "Jewish state," "the safety," "to exist," "“My," "commitment," "safety," "Jewish," "people,," "security," "right," "exist," "independent," "state," and "even".
# _____________________________________
#
# House Speaker Emerita Nancy Pelosi, who had been one of the notable holdouts, initially encouraging a primary to strengthen the eventual nominee, said she was lending her “enthusiastic support” to Harris’ effort to lead the party.
#
# This sentence is positive because it contains the words/phrases "enthusiastic support," "nominee,," and "“enthusiastic".
# _____________________________________
#
# Biden has faced criticism from Republicans and Democrats as he’s tried to balance unwavering support for Israel’s security with sympathy for the Palestinians killed and suffering in Gaza.
#
# This sentence is negative because it contains the words/phrases "killed," and "criticism".
# _____________________________________
#
# Delta’s technical issues are comparable to those that occurred with Southwest Airlines during the 2022 holiday travel season. The Dallas-based airline canceled thousands of flights and left millions of travelers stranded.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# He also said hello to Harris, adding, “I want to say to the team: Embrace her, she’s the best,” prompting cheers in the room.
#
# This sentence is positive because it contains the words/phrases "prompting," "adding," "to say," "the room," "the team," "’s," "want," "also said," "also," "hello," "adding,," "team:," "Embrace," and "best,”".
# _____________________________________
#
# Officials said the outbreak of Listeria monocytogenes is linked to meat sliced at deli counters.
#
# This sentence is negative because it contains the word/phrase "outbreak".
# _____________________________________
#
# The stock market has suddenly turned upside down. Few investors saw the shift coming, and many are puzzled by what is behind it.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# "She's totally on top of the issues. Kalama has advocated for the issues for the city and she's a good friend," Duggan said.
#
# This sentence is positive because it contains the words/phrases "good friend," "has advocated," "a good friend," and "advocated".
# _____________________________________
#
# Visa's third-quarter revenue growth fell short of Wall Street expectations as steep borrowing costs limited consumer spending, sending shares of the world's largest payments processor down 2.1% in extended trading.
#
# This sentence is negative because it contains the words/phrases "largest payments," "the world's largest payments," and "largest".
# _____________________________________
#
# “The threat of repeating the past is so great,” Johnson said. “There are some who would prefer to criticize Israel and lecture them on their military tactics…than punish the terrorists who perpetrated these horrific crimes.”
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# Even if you have no professional use for AI, don't worry -- the process is so fun that anyone can (and should) try it out.
#
# This sentence is positive because it contains the words/phrases "professional use," "Even have," "no professional use," "do n't worry," "Even," and "fun".
# _____________________________________
#
# Not long after posting that note on social media, he endorsed his Vice President Kamala Harris in his stead.
#
# This sentence is positive because it contains the words/phrases "his Vice President Kamala Harris," "social media," "endorsed," "long," "social," "President," and "Kamala".
# _____________________________________
#
# The reality confronting us is that of a sullen and resentful Russia, convinced that history, morality and even divinity is on its side in a de facto existential war with the West.
#
# This sentence is negative because it contains the word/phrase "a sullen and resentful Russia".
# _____________________________________
#
# Former President Donald Trump said in a new interview with Fox News that the wound on his ear from the Pennsylvania assassination attempt was “getting much better” and that he was now “down to the small bandages.”
#
# This sentence is positive because it contains the words/phrases "said," "the wound," "a new interview," "President," "much," "better”," and "small".
# _____________________________________
#
# The Kentucky governor secured his reputation as a rising party star by beating Donald Trump-endorsed candidates in a Republican stronghold.
#
# This sentence is positive because it contains the words/phrases "his reputation," "secured," "Donald Trump-endorsed candidates," "a rising party star," "rising," "Republican stronghold," and "endorsed".
# _____________________________________
#
# If your flight is canceled or significantly delayed and you don’t want to be rebooked and you instead want a refund, you can go to delta.com/refund to apply for a refund.
#
# This sentence is negative because it contains the words/phrases "your flight," "a refund," "canceled," "significantly delayed," "flight," and "significantly".
# _____________________________________
#
# Cities with larger concentrations of psychologists and psychiatrists make it easier to find a mental health professional you like and get on their schedule in a timely manner.
#
# This sentence is positive because it contains the words/phrases "larger concentrations," "timely manner," "make," "larger," "easier," and "timely".
# _____________________________________
#
# The Food and Drug Administration also gets a bounce of nearly $500 million in the new budget to $7.2 billion, with an aim of enhancing food safety and nutrition, advancing medical product safety and helping to "support supply chain resiliency," according to FDA Commissioner Robert Califf.
# This sentence is positive because it contains the words/phrases "helping," "a bounce," "advancing," "medical product," "also gets," "enhancing," "the new budget," "new and budget".
# _____________________________________
#
# Analysts at BMO Capital Markets also highlighted CRTO as the net beneficiary, adding that The Trade Desk (NASDAQ:TTD) also appears well-positioned with no deprecation.
#
# This sentence is positive because it contains the words/phrases "adding," "well positioned," "also appears," "also highlighted," "net beneficiary," "no deprecation," "the net beneficiary," "also," "highlighted," "net," "beneficiary,," "(NASDAQ:TTD)," "well-positioned," and "deprecation.".
# _____________________________________
#
# The two deaths occurred in Illinois and New Jersey.
#
# This sentence is negative because it contains the word/phrase "Jersey.".
# _____________________________________
#
# That's why it's hard to find Ukrainians these days who speak well of any Russians.
#
# This sentence is negative because it contains the word/phrase "hard".
# _____________________________________
#
# Golos said the March 15-17 election was “characterized by unprecedented levels of violence and emotional tension.”
#
# This sentence is negative because it contains the word/phrase "violence".
# _____________________________________
#
# Yes. Biden endorsed Harris for the presidential position in the November election after stepping down Sunday. According to a post from Harris on X, she hopes "to unite the Democratic Party--and unite our nation--to defeat Donald Trump and his extreme Project 2025 agenda."
#
# This sentence is positive because it contains the words/phrases "to defeat," "the presidential position," "endorsed," and "defeat".
# _____________________________________
#
# Also in New Jersey, Herb Conaway, the Democratic nominee for Congress in the state's Third Congressional District, issued a statement on President Biden’s decision to pass the torch to a new generation of leaders.
#
# This sentence is positive because it contains the words/phrases "the state's Third Congressional District," "leaders," "a new generation," "Also issued," "new generation," "the torch," "President," "pass," "torch," "new," "generation," and "leaders.".
# _____________________________________
#
# Want to read more stories like this? POLITICO Weekend delivers gripping reads, smart analysis and a bit of high-minded fun every Friday. Sign up for the newsletter.
#
# This sentence is positive because it contains the words/phrases "Sign," "a bit," "gripping," "high-minded fun," "gripping reads," "to read," "smart analysis," "minded fun," "the newsletter," "more stories," "read," "smart," "analysis," "bit," and "fun".
# _____________________________________
#
# Fraudulent votes amounted to at least 31.6 million — or nearly half of all ballots cast for Vladimir Putin — according to estimates by Novaya Gazeta Europe.
#
# This sentence is negative because it contains the words/phrases "Fraudulent votes," "Fraudulent," and "least".
# _____________________________________
#
# Germany also sharply criticized the vote. “Russia, as the chancellor has already said, is now a dictatorship and is ruled by Vladimir Putin in an authoritarian manner,” said Chancellor Olaf Scholz's spokeswoman, Christina Hoffmann.
#
# This sentence is negative because it contains the words/phrases "sharply criticized," "also sharply and criticized".
# _____________________________________
#
# Microsoft Just Shared 1 Big Tip for Managing AI at Your Business
#
# This sentence is positive because it contains the words/phrases "Microsoft Just Shared 1 Big Tip," "Shared," and "Big".
# _____________________________________
#
# Access unmatched financial data, news and content in a highly-customised workflow experience on desktop, web and mobile.
#
# This sentence is positive because it contains the words/phrases "a highly-customised workflow experience," "Access unmatched financial data," "highly customised," "Access," and "unmatched".
# _____________________________________
#
# New Jersey has had two people hospitalized because of a listeria infection and New York has seen seven people hospitalized, the most of any state.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# Tap into the ideas shaping and driving the U.S. innovation economy
#
# This sentence is positive because it contains the words/phrases "innovation economy," "driving," "the U.S. innovation economy," "Tap," "ideas," and "innovation".
# _____________________________________
#
# "The best path forward for the Democratic Party is to quickly unite behind Vice President Harris and refocus on winning the presidency," Shapiro said. "The contrast in this race could not be clearer and the road to victory in November runs right through Pennsylvania — where this collective work began."
#
# This sentence is positive because it contains the words/phrases "best path," "collective work," "to quickly unite," "this collective work," "winning," "The best path," "quickly unite," "best," "unite," and "clearer".
# _____________________________________
#
# Kyle Vogt cofounded Twitch and Cruise, two companies that achieved billion-dollar exits in sales to Amazon and General Motors, respectively.
#
# This sentence is positive because it contains the words/phrases "respectively achieved," "Kyle Vogt," "Cruise,," "achieved," "billion-dollar," "Motors,," and "respectively.".
# _____________________________________
#
# Published since September 1843 to take part in “a severe contest between intelligence, which presses forward, and an unworthy, timid ignorance obstructing our progress.”
#
# This sentence is negative because it contains the words/phrases "timid ignorance," "severe contest," "to take," "our progress," "part," "an unworthy, timid ignorance," "a severe contest," "September," "obstructing," "since," "severe," "unworthy,," "timid," "ignorance," and "progress.”".
# _____________________________________
#
# Russian autocrat Vladimir Putin late on Sunday unsurprisingly claimed victory in what Russia said was an election for its presidency, solidifying his rule throughout the remainder of this decade and into the 2030s.
#
# This sentence is positive because it contains the words/phrases "victory," "unsurprisingly claimed," and "presidency,".
# _____________________________________
#
# In spite of maintaining stealth until now, Mytra has already drummed up interest with big names. The startup has a pilot with grocery giant Albertsons, among others.
#
# This sentence is positive because it contains the words/phrases "already drummed," "has already drummed," and "now,".
# _____________________________________
#
# Remember the SPAC Craze? More Than a Third of Them Have Liquidated Since 2020
#
# This sentence is negative because it contains the words/phrases "Them," "Have Liquidated," "SPAC," "Craze?," "Third," "Liquidated," and "2020".
# _____________________________________
#
# NATO Secretary-General Jens Stoltenberg said Russia's presidential election was "not free nor fair" and only confirms that Russia is "an authoritarian society."
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# Even so, it's obvious that ChatGPT 4 is smarter than the other AI chatbots. Its answers are more thoughtful, and it can synthesize complex bits of information to produce useful sentences, even if it takes a bit of time to process. It's also less prone to hallucinate.
#
# This sentence is positive because it contains the words/phrases "useful sentences," "even takes," "to produce," "to hallucinate," "complex bits," "can synthesize," "the other AI chatbots," "to process," "Even," "so,," "smarter," "even," and "also".
# _____________________________________
#
# Apple Moves Forward With Foldable iPhone
# Save 25% and learn more
#
# This sentence is positive because it contains the words/phrases "Forward," and "iPhone
# Save".
# _____________________________________
#
# While I found the best overall AI image generator is Image Creator from Microsoft Designer, due to its free-of-charge, high-quality results, other AI image generators perform better for specific needs. For the full roundup of the best AI image generators, keep reading.
#
# This sentence is positive because it contains the words/phrases "the best AI image generators," "the full roundup," "better perform," "other AI image generators," "image generators," "specific needs," "full roundup," "the best overall AI image generator," "quality results," and "best".
# _____________________________________
#
# In a study last month, the World Health Organization warned that since 2010 a growing number of adults aren't getting enough exercise. A lack of physical activity puts people at risk of heart attacks and strokes, Type 2 diabetes, dementia and certain cancers.
# This sentence is negative because it contains the word/phrase "are n't getting".
# _____________________________________
#
# “We’ve been thrown into an emotional tailspin,” is how Levin described President Joe Biden’s abrupt departure from the 2024 campaign this weekend and his quick endorsement of Vice President Kamala Harris. “What next? An enormous feeling of relief along with an enormous feeling of anxiety.”
#
# This sentence is negative because it contains the words/phrases "abrupt departure," "anxiety," "President Joe Biden’s abrupt departure," "thrown," "tailspin,”," "next?," and "anxiety.”".
# _____________________________________
#
# Location is only one part of healthy living. Ultimately, it’s individual behaviors executed on a daily basis that have the most impact on getting and staying healthy. The best part is that you don’t have to do it alone.
#
# This sentence is positive because it contains the words/phrases "staying," "a daily basis," "the most impact," "individual behaviors," "do n’t have," "best part," "most impact," "to alone do," "The best part," "getting," "only one part," "healthy living," "Ultimately ’s," "executed," "daily basis," "part," "Ultimately,," "best," "don’t," and "alone.".
# _____________________________________
#
# Biden aides and Democratic allies welcomed the split screen, even with the potential that it could blot out coverage of the president’s speech.
#
# This sentence is positive because it contains the words/phrases "Democratic allies," and "welcomed".
# _____________________________________
#
# After much back and forth, Google has decided to keep third-party cookies in its Chrome browser. Turns out all the fuss over the years wasn’t in vain after all; the ad industry’s cries have finally been heard.
#
# This sentence is positive because it contains the words/phrases "vain," "has decided," "have finally heard," "Google," "its Chrome browser," "much," "forth,," "decided," "years," "wasn’t," and "finally".
# _____________________________________
#
# "His attacks on academic freedom, intentionally depicting protests in a negative light, failure to care for and listen to Palestinian Pennsylvanians whose families are being massacred day in and out by Israeli government, and his behind-the-scenes antagonization of community organizations cannot be ignored and easily forgiven," it continued.
#
# This sentence is negative because it contains the words/phrases "intentionally depicting," "can not and ignored".
# _____________________________________
#
# Delta executives previously said remedying this issue would take days.
#
# This sentence is negative because it contains the words/phrases "would take," "Delta executives," "this issue," "days," "Delta," and "issue".
# _____________________________________
#
# McGowan said she founded the company due to the rapid rise in cyber attacks these past years and the increased fears people have about cybersecurity.
#
# This sentence is negative because it contains the words/phrases "increased," "due," "past," and "years".
# _____________________________________
#
# These symbolic demonstrations will not impact the final result, and, in many ways, they show how weakened the Russian opposition has become under Putin’s iron-fisted rule. But they follow a storied tradition of civil disobedience across the world in the face of unjust voting processes.
#
# This sentence is negative because it contains the words/phrases "These symbolic demonstrations," "voting processes," "will not impact," "unjust voting processes," "symbolic demonstrations," "unjust voting," "demonstrations," "ways,," "weakened," and "voting".
# _____________________________________
#
# “People think exercise means working out and working out means ‘I have to go somewhere and do something…and I have to go at it hard,’” Volpe says. “The best type of activity is the one that they can do and the one that they will do.”
#
# This sentence is positive because it contains the words/phrases "activity," "working," "The best type," "to somewhere go," "best type," "something," "“The," "best," "type," and "one".
# _____________________________________
#
# Listeria can spread through cross contamination on deli equipment, kitchen surfaces, foods and human contact. The bacteria can survive cold temperatures like this in fridges.
#
# This sentence is negative because it contains the words/phrases "cross contamination," "spread," and "contamination".
# _____________________________________
#
# — The Chandra X-ray spacecraft may soon go dark, threatening a great deal of astronomy
#
# This sentence is negative because it contains the words/phrases "may soon go," and "threatening".
# _____________________________________
#
# Cookies were originally supposed to go away in 2022, but Google would delay those plans three times, with the most recent postponement happening in April.
#
# This sentence is negative because it contains the words/phrases "the most recent postponement happening," "would delay," and "delay".
# _____________________________________
#
# "When we protest, protest peacefully and make our voices heard," Biden said. "I understand that's America. But there is no place on any campus in America for anti-Semitism or hate speech, or threats of violence of any kind, whether against Jews or anyone else."
#
# This sentence is negative because it contains the words/phrases "America," "peacefully protest," and "place".
# _____________________________________
#
# ...
# _____________________________________
#
# "Thank you, President Biden, for always putting our country first," the Democratic two-term governor wrote.
#
# This sentence is positive because it contains the words/phrases "term governor," "always first putting," "always putting," "the Democratic two-term governor," "our country," "Thank," "always," "putting," "country," "first,"," "Democratic," "two-term," and "governor".
# _____________________________________
#
# Back-to-school technology is on sale and hugely discounted at Walmart right now.
#
# This sentence is positive because it contains the words/phrases "hugely discounted," "sale," "school technology," "Walmart," "hugely now discounted," "school," "Back-to-school," "technology," "hugely," "discounted," and "now.".
# _____________________________________
#
# One key theme in the budget plan is an effort to help families afford their basic needs, as the impact of inflation hitting a four-decade high in 2022 continues to leave many voters feeling as though they're worse off under Biden.
#
# This sentence is negative because it contains the words/phrases "an effort," "a four-decade high," "effort," "leave," "voters," and "worse".
# _____________________________________
#
# In an “updated approach” announced in a blog post today, Google revealed it won’t be “deprecating third-party cookies.” Instead, it’s introducing a “new experience in Chrome” that lets users make an informed choice across their web browsing, which they’d be able to adjust at any time.
#
# This sentence is positive because it contains the words/phrases "Instead ’s introducing," "informed choice," "updated," "a “new experience," "wo n’t be deprecating," "new experience," and "won’t".
# _____________________________________
#
# Israeli forces seized the main border crossing between Egypt and southern Gaza earlier today, in what Israel and the US say is a limited offensive rather than a full-out offensive on the city.
#
# This sentence is negative because it contains the words/phrases "seized," "Israeli and forces".
# _____________________________________
#
# Some held signs thanking Biden, including one on a stroller that read: “My future is brighter because of you.”
#
# This sentence is positive because it contains the words/phrases "Some held signs," "read," "held signs," "a stroller," "My future," "including," "thanking," "held," "stroller," "read:," "future," and "brighter".
# _____________________________________
#
# Officials added: 'Our investigation is ongoing to determine which deli meat may be contaminated. We do not have information to show that people are getting sick from prepackaged deli meats.'
#
# This sentence is negative because it contains the word/phrase "sick".
# _____________________________________
#
# Beshear has presided over record economic growth in Kentucky, and he typically begins his briefings by promoting the state’s latest economic wins. He frequently mentions his Christian faith and how it guides his policymaking.
#
# This sentence is positive because it contains the words/phrases "the state’s latest economic wins," "his Christian faith," "economic growth," "record economic growth," "has presided," "record," "growth," and "latest".
# _____________________________________
#
# ImageFX also includes suggestions for the style you'd like your image rendered in, such as photorealistic, 35mm film, minimal, sketch, handmade, and more. This combination of features makes ImageFX the perfect for beginners who want to experiment.
#
# This sentence is positive because it contains the words/phrases "ImageFX also includes," "rendered," "also includes," "the perfect," "'d like," "also," and "perfect".
# _____________________________________
#
# The best no-frills AI image generator with unlimited prompts and a straightforward interface.
#
# This sentence is positive because it contains the words/phrases "a straightforward interface," "The best no-frills AI image generator," "best no," "straightforward interface," and "best".
# _____________________________________
#
# In a statement, it hailed the courage of "the many Russian citizens who peacefully protested against this attack on their fundamental political rights".
#
# This sentence is positive because it contains the words/phrases "peacefully protested," "the courage," "hailed," and "courage".
# _____________________________________
#
# The death toll in the southern Ukrainian city of Odesa has now risen to 14 while a further 46 have been injured, according to the region’s governor.
#
# This sentence is negative because it contains the words/phrases "has now risen," "death toll," "The death toll," and "injured,".
# _____________________________________
#
# Russia has occupied Crimea since invading the peninsula in 2014. A bridge connecting it to the Russian mainland was opened in 2018, but has been attacked and forced to close twice since the start of the war in Ukraine.
#
# This sentence is negative because it contains the word/phrase "attacked".
# _____________________________________
#
# Rising from a state House seat representing his hometown of Abington to the governor’s mansion, Shapiro built a reputation for being a hard worker and a skilled negotiator. And he has projected those attributes onto his administration’s brand with the slogan “Get S**t Done.”
#
# This sentence is positive because it contains the word/phrase "has projected".
# _____________________________________
#
# Criteo also noted that, based on its testing, Google Ad Manager captured the majority of ad spend against Criteo’s treatment group, which suggests that the Privacy Sandbox would boost GAM’s market share from 23% to 83%.
# This sentence is positive because it contains the words/phrases "would boost," "market share," "captured," "would," and "boost".
# _____________________________________
#
# What’s next. Google hasn’t provided a specific timeline for the new approach, likely to avoid the pitfalls of previous delays.
#
# This sentence is negative because it contains the words/phrases "has n’t likely provided," "hasn’t," and "provided".
# _____________________________________
#
# Context: There was a surge in police reform talks following the murder of George Floyd, a Black man who was killed by Minneapolis police in 2020. But the talks ultimately collapsed in September 2021, with negotiators saying their differences were simply too vast.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# A multi-state listeria outbreak linked to deli meat has left 28 people hospitalized and two dead.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# If your travel nightmare has led to additional meal, transportation and lodging expenses, save your receipts.
#
# This sentence is negative because it contains the words/phrases "your travel nightmare," "travel nightmare," "has led," "lodging expenses," "nightmare," and "expenses,".
# _____________________________________
#
# Dr. Kevin O'Connor said in an update released by the White House that Biden's Covid "symptoms have resolved almost completely."
#
# This sentence is positive because it contains the words/phrases "have completely resolved," "resolved," "almost," and "completely."".
# _____________________________________
#
# Some context: Multiple sources have told CNN that Schumer and Jeffries will endorse Harris as soon as today. At a news conference earlier today, Jeffries said he was “excited” to meet with Harris later in the day.
#
# This sentence is positive because it contains the words/phrases "will soon endorse," "have told," "to later meet," and "“excited”".
# _____________________________________
#
# In a statement to NPR, Delta Air Lines acknowledged the Department of Transportation’s notice of the investigation and said it is "fully cooperating" with the department.
#
# This sentence is positive because it contains the words/phrases "acknowledged," "is fully cooperating," "fully cooperating," "NPR,," "Transportation’s," and "cooperating"".
# _____________________________________
#
# Pennsylvania Republicans are reacting positively to Trump’s choice of J.D. Vance — a veteran, venture capitalist and one-time Trump critic — as his pick for vice president.
#
# This sentence is positive because it contains the words/phrases "are positively reacting," and "positively".
# _____________________________________
#
# The environment in which kids grow up today is hostile to human development.
#
# This sentence is negative because it contains the word/phrase "hostile".
# _____________________________________
#
# "History will remember Joe Biden as not just a quitter, which he is, but one of the worst presidents in the United States of America," Vance told supporters in Radford, Virginia. "But, my friends, Kamala Harris is a million times worse."
#
# This sentence is negative because it contains the words/phrases "worst presidents," "the worst presidents," "not just a quitter," "worst," and "worse."".
# _____________________________________
#
# Armed men were guarding Russian high-ranking representatives and checking Ukrainian passports of Avdiivka residents, mostly elderly people who became emaciated shadows of themselves after months of suffering and fear.
#
# This sentence is negative because it contains the word/phrase "emaciated shadows".
# _____________________________________
#
# Many had hoped Navalny’s death would spark a wave of opposition that would sweep him out of power
#
# This sentence is negative because it contains the words/phrases "power," "Navalny’s death," and "death".
# _____________________________________
#
# Amazon Prime Day is finally here with some amazing deals. If you’ve had your eye on a LEGO set, now is the time to act.
#
# This sentence is positive because it contains the words/phrases "to act," "’ve had," "a LEGO set," "amazing deals," "some amazing deals," "the time," "your eye," "Amazon," "finally," "amazing," "eye," and "LEGO".
# _____________________________________
#
# Biden’s campaign: Biden’s campaign and its connected fundraising organizations raised $53 million in February.
#
# This sentence is positive because it contains the words/phrases "connected fundraising," "raised," "fundraising organizations," "its connected fundraising organizations," and "million".
# _____________________________________
#
# Josh Shapiro is known for his practical approach to politics and ability to work with both parties.
#
# This sentence is positive because it contains the words/phrases "his practical approach," "ability," "practical approach," and "known".
# _____________________________________
#
# We are independent, beholden to no corporate interests or profit motives. We’re strictly nonpartisan, with no political agenda, no policy preferences, and no opinion content. And we are nonprofit, allowing us to offer all of our journalism at no cost thanks to the generosity of thousands of people across Pennsylvania.
#
# This sentence is positive because it contains the words/phrases "political agenda," "cost thanks," "no corporate interests," "no political agenda," "the generosity," and "cost".
# _____________________________________
#
# Burgos said choosing the right vice presidential nominee is crucial to secure the votes of moderate Republicans, “who understand that you have to govern and not throw tantrums.”
#
# This sentence is positive because it contains the words/phrases "right vice," "understand," "not throw," "presidential nominee," "the right vice presidential nominee," and "crucial".
# _____________________________________
#
# The Atlanta-based carrier lags behind competitors in returning to normal operations after the CrowdStrike software update grounded flights globally on Friday.
#
# This sentence is negative because it contains the words/phrases "grounded flights," "update," "grounded," "normal operations," "the CrowdStrike software," "The Atlanta-based carrier lags," "lags," and "software".
# _____________________________________
#
# We cannot afford to leave journalism — a vital component of our beloved communities — in the hands of absent corporate owners, hedge funds, and agenda-driven billionaires. Many have spent the past two decades gutting our local news institutions.
#
# This sentence is negative because it contains the word/phrase "can not afford".
# _____________________________________
#
# To follow Corporate Natalie’s humorous adventures juggling work and life, check out her Instagram page. Learn more here about how Adobe Acrobat AI Assistant can help you unlock new value from your documents to create impactful content and level up your productivity.
#
# This sentence is positive because it contains the words/phrases "impactful content," "your productivity," "here Learn," "to create," "To follow," "Corporate Natalie’s humorous adventures," "new value," "humorous and adventures".
# _____________________________________
#
# Shapiro was appearing with Environmental Protection Agency Secretary Mike Reagan and Allegheny County Executive Sara Innamorato to celebrate securing nearly $400 million to cut pollution. The money will help industrial facilities like Castle Builders Supply run cleaner operations, and it will fund carbon capture technology to lower greenhouse gas emissions.
#
# This sentence is positive because it contains the words/phrases "to celebrate," "was appearing," "to cut," "celebrate," and "lower".
# _____________________________________
#
# “Kamala Harris is going to be an amazing president,” he said.
#
# This sentence is positive because it contains the words/phrases "is going," "an amazing president," "amazing president," "going," and "amazing".
# _____________________________________
#
# She noted that she got to "personally know President Joe Biden" in her time in office and thanked him for his service to the country.
#
# This sentence is positive because it contains the words/phrases "the country," "his service," "noted," "personally know," "to personally know," "her time," and ""personally".
# _____________________________________
#
# WASHINGTON — President Joe Biden warned Tuesday of rising antisemitism in the U.S. and said too many are forgetting the attack on Israel in October.
# This sentence is negative because it contains the word/phrase "warned".
# _____________________________________
#
# Remember: Earlier today, GOP Rep. Tim Burchett described Harris as a “DEI hire,” a comment characterized as racist and offensive by Congressional Black Caucus Chairman Steve Horsford.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# The FBI Boston Division recovered 22 artifacts stolen from Japan, including the artwork above. During World War II, various treasures from the Ryukyu Kingdom were stolen.
#
# This sentence is negative because it contains the words/phrases "stolen," "treasures," and "stolen.".
# _____________________________________
#
# Listeria symptoms usually start within two weeks of eating food contaminated with the bacteria, but may start as early as the same day or as late as 10 weeks after, the CDC said. Symptoms include fever, muscle aches, tiredness, headache, stiff neck, confusion, loss of balance and seizures.
#
# This sentence is negative because it contains the word/phrase .
# _____________________________________
#
# Microsoft Just Shared 1 Big Tip for Managing AI at Your Business
#
# This sentence is positive because it contains the words/phrases "Microsoft Just Shared 1 Big Tip," "Shared," and "Big".
# _____________________________________
#
# Improve the Wellbeing of Children and Families. High-quality early childhood education improves the lives of both children and their parents. HHS is committed to supporting the country’s most vulnerable children and families.
#
# This sentence is positive because it contains the words/phrases "High-quality early childhood education," "vulnerable children," "the country’s most vulnerable children," "early childhood," "committed," "supporting," "Wellbeing," "early," and "country’s".
# _____________________________________
